# %% [markdown]
# ### Documentacao Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\formulario.html"
navegador.get(arquivo)

# %% [markdown]
# #### Botao Padrao (clicar em botao)

# %%
navegador.find_element(By.XPATH, '/html/body/form/input[1]').click()
pop_up = navegador.switch_to.alert
pop_up.accept()

# %% [markdown]
# #### Dica, esteja atento ao atributo "value" dos inputs, ele pode te ajudar
#
# - .text
# - .get_attribute("value")
# - .is_selected

# %% [markdown]
# #### Botao de Selecao estilo Checkbox (clicar no botao)

# %%
# clicar no botao
navegador.find_element(By.XPATH, '/html/body/form/input[2]').click()

# %%
# verificar o valor do botao
selecionado = navegador.find_element(By.XPATH, '/html/body/form/input[2]').is_selected()
print(selecionado)
# Out:
# True

# %% [markdown]
# #### Botao de Selecao de Cores (enviar valor)

# %%
# preencher a cor
navegador.find_element(By.XPATH, '/html/body/form/input[4]').send_keys('#0000ff')
navegador.find_element(By.XPATH, '/html/body/form/input[5]').send_keys('#00ff00')

# %%
# verificar qual a cor foi selecionada
valor = navegador.find_element(By.XPATH, '/html/body/form/input[4]').get_attribute('value')
print(valor)
# Out:
# #0000ff

# %% [markdown]
# #### Botao de Datas (enviar valor)

# %%
# preencher o valor
navegador.find_element(By.XPATH, '/html/body/form/input[6]').send_keys('01/01/2001')

# %%
# pegar o valor
data = navegador.find_element(By.XPATH, '/html/body/form/input[6]').get_attribute('value')
print(data)
# Out:
# 2001-01-01

# %% [markdown]
# #### Botao de Datas com Horas (enviar valor)

# %%
# preenchendo
from selenium.webdriver.common.keys import Keys
navegador.find_element(By.XPATH, '/html/body/form/input[7]').send_keys('29/12/1979', Keys.TAB, '09:30')

# %%
# pegando o valor
valor =  navegador.find_element(By.XPATH, '/html/body/form/input[7]').get_attribute('value')
print(valor)
# Out:
# 1979-12-29T09:30

# %% [markdown]
# #### Botao para selecionar o arquivo (enviar valor com caminho completo)

# %%
# preenchendo
caminho = os.getcwd()
arquivo = caminho + r'\formulario.html'
navegador.find_element(By.XPATH, '/html/body/form/input[8]').send_keys(arquivo)

# %%
# pegar o valor
valor = navegador.find_element(By.XPATH, '/html/body/form/input[8]').get_attribute('value')
print(valor)
# Out:
# C:\fakepath\formulario.html

# %% [markdown]
# #### Botao para selecionar mes e ano (enviar valor)

# %%
# preenche
navegador.find_element(By.XPATH, '/html/body/form/input[9]').send_keys('dezembro', Keys.TAB, '2024')
# pegar o valor
valor = navegador.find_element(By.XPATH, '/html/body/form/input[9]').get_attribute('value')
print(valor)
# Out:
# 2024-12

# %% [markdown]
# #### Campos Numericos

# %%
navegador.find_element(By.XPATH, '/html/body/form/input[10]').clear()
navegador.find_element(By.XPATH, '/html/body/form/input[10]').send_keys('1234567890')
valor = navegador.find_element(By.XPATH, '/html/body/form/input[10]').get_attribute('value')
print(valor)
# Out:
# 1234567890

# %% [markdown]
# #### Campos de Senha

# %%
# preencher
navegador.find_element(By.XPATH, '/html/body/form/input[11]').send_keys('abc982')
# pego o valor
valor = navegador.find_element(By.XPATH, '/html/body/form/input[11]').get_attribute('value')
print(valor)
# Out:
# abc982

# %% [markdown]
# #### RadioButtons (botoes que so consegue marcar 1)

# %%
navegador.find_element(By.XPATH, '/html/body/form/input[13]').click()

# %%
valor = navegador.find_element(By.XPATH, '/html/body/form/input[13]').is_selected()
print(valor)
# Out:
# True

# %% [markdown]
# #### Slider (enviar valor)

# %%
# pegar o valor
valor = navegador.find_element(By.XPATH,'/html/body/form/input[15]').get_attribute('value')
print(valor)
# Out:
# 50

# %%
# preencher o valor
navegador.find_element(By.XPATH,'/html/body/form/input[15]').clear()
for i in range(80 - 50):
    navegador.find_element(By.XPATH,'/html/body/form/input[15]').send_keys(Keys.ARROW_RIGHT)

# %% [markdown]
# #### Caixa de Texto

# %%
# preencher
navegador.find_element(By.XPATH,'/html/body/form/input[16]').send_keys('Náutico')

# %%
# pegar o valor
valor = navegador.find_element(By.XPATH,'/html/body/form/input[16]').get_attribute('value')
print(valor)
# Out:
# Náutico

# %% [markdown]
# #### Caixa de Horas

# %%
# preencher valor
navegador.find_element(By.XPATH,'/html/body/form/input[17]').send_keys('6:39')

# %%
# pegar o valor
valor = navegador.find_element(By.XPATH,'/html/body/form/input[17]').get_attribute('value')
print(valor)
# Out:
# 06:39

# %% [markdown]
# #### Caixa de Data Personalizada (Semanal)

# %%
navegador.find_element(By.XPATH,'/html/body/form/input[18]').clear()
navegador.find_element(By.XPATH,'/html/body/form/input[18]').send_keys('01','2025')

valor = navegador.find_element(By.XPATH, '/html/body/form/input[18]').get_attribute('value')
print(valor)
# Out:
# 2025-W01

# %% [markdown]
# #### Blocos de texto (enviar valor)

# %%
navegador.find_element(By.XPATH,'//*[@id="story"]').clear()
navegador.find_element(By.XPATH,'//*[@id="story"]').send_keys('Olá Mundo,', Keys.ENTER, 'Me chamo Cláudio',Keys.ENTER, 'estudo Python',Keys.ENTER, 'Na Hashtag', Keys.ENTER, 'Quero trabalhar com dados' )

# %% [markdown]
# #### Selecionando itens de uma lista

# %%
# preencher o valor
navegador.find_element(By.XPATH,'/html/body/form/select[1]').send_keys('C')

# %%
# pegando o valor
valor = navegador.find_element(By.XPATH,'/html/body/form/select[1]').get_attribute('value')
print(valor)
# Out:
# c

# %%
# clicando para selecionar
import time
navegador.find_element(By.XPATH,'/html/body/form/select[1]').click()
time.sleep(0.3)
navegador.find_element(By.XPATH,'/html/body/form/select[1]/option[1]').click()

# %%
# com o select
# proxima aula
# https://www.selenium.dev/pt-br/documentation/webdriver/elements/select_lists/

from selenium.webdriver.support.select import Select

elemento = navegador.find_element(By.TAG_NAME, 'select')
elemento_select = Select(elemento)

elemento_select.select_by_index(1)

# %%
elemento_select.select_by_visible_text('C')

# %%
# ler o item selecionado
lista_itens = elemento_select.all_selected_options
print(lista_itens)
print(lista_itens[0])
valor = lista_itens[0].get_attribute('value')
print(valor)
# find_element = elemento
# find_elements = [elemento1, elemento2, elemento3]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="bc0b11101e454072fe7e2623842c8978", element="f.BAA53D0AD1F382266C2CAB1359DCBA2F.d.3CC47316436A010BD421CD60A76B4405.e.235")>]
# <selenium.webdriver.remote.webelement.WebElement (session="bc0b11101e454072fe7e2623842c8978", element="f.BAA53D0AD1F382266C2CAB1359DCBA2F.d.3CC47316436A010BD421CD60A76B4405.e.235")>
# c
